# %%
import requests
from bs4 import BeautifulSoup

# 응답 객체 받아오기
response = requests.get('https://www.naver.com/')

# 객체 안에 html 속성 가져오기
html = response.text # html 속성을 문자열로 가져옴
soup = BeautifulSoup(html, 'html.parser') # html.parser의 도움으로 html 문서를 파싱하는 방법
anchor = soup.select_one("#NM_set_home_btn") # id가 NM_set_home_btn인 태그를 찾아라
anchor.text # anchor의 text를 가져와라
dir(anchor) # anchor의 속성을 보여줌 (dir은 디렉토리를 의미함) #스프도 객체고 앵커도 객체
# Out:
# ['DEFAULT_INTERESTING_STRING_TYPES',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_find_all',
#  '_find_one',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_namespaces',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contents',
#  'decode',
#  'decode_contents',
#  'decompose',
# ...
