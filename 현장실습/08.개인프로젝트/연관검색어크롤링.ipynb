# %%
#https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css
#https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css

# %%
import requests
import json

response = requests.get("https://ac.search.naver.com/nx/ac?q=유튜브 ㄱ&con=0&frm=nv&ans=2&r_format=json&r_enc=UTF-8&r_unicode=0&t_koreng=1&run=2&rev=4&q_enc=UTF-8&st=100&_callback=_jsonp_5")

data = response.text
data = data.replace('_jsonp_5(', '').replace(')', '')
data = json.loads(data)
items = data['items'][0]
for item in items:
    print(item[0])
# Out:
# 유튜브 광고
# 유튜브 검은화면
# 유튜브 고객센터
# 유튜브 검색기록
# 유튜브 광고 제거
# 유튜브 검은색
# 유튜브 검색기록 삭제
# 유튜브 검정
# 유튜브 가족계정
# 유튜브 검색어

# %%
#같은 결관데 리플레이스 안쓰고 콜백만 지워서
import requests
import json
import openpyxl
from bs4 import BeautifulSoup


response = requests.get("https://ac.search.naver.com/nx/ac?q=유튜브 ㄱ&con=0&frm=nv&ans=2&r_format=json&r_enc=UTF-8&r_unicode=0&t_koreng=1&run=2&rev=4&q_enc=UTF-8&st=100&_callback=")

data = response.text
data = json.loads(data)
items = data['items'][0]
for item in items:
    print(item[0])
# Out:
# 유튜브 광고
# 유튜브 검은화면
# 유튜브 고객센터
# 유튜브 검색기록
# 유튜브 광고 제거
# 유튜브 검은색
# 유튜브 검색기록 삭제
# 유튜브 검정
# 유튜브 가족계정
# 유튜브 검색어

# %%
main_keyword = input('검색어를 입력하세요: ')
sub_list = ['ㄱ', 'ㄴ', 'ㄷ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅅ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']

for sub in sub_list:
    keyword = main_keyword + ' ' + sub
    response = requests.get(f"https://ac.search.naver.com/nx/ac?q={keyword}&con=0&frm=nv&ans=2&r_format=json&r_enc=UTF-8&r_unicode=0&t_koreng=1&run=2&rev=4&q_enc=UTF-8&st=100&_callback=")
    data = response.text
    
    data = json.loads(data)
    items = data['items'][0]
    for item in items:
        print(item[0])

# %%
wb = openpyxl.Workbook() # 워크북 생성
ws = wb.active # 현재 활성화된 sheet 선택
ws.title = keyword # sheet 이름 변경


ws.append(["제목", "링크", "내용"])

    for article in articles:
        anchor = article.select_one(".news_tit")
        title = anchor.text
        link = anchor.attrs['href']
        content = article.select_one(".api_txt_lines.dsc_txt_wrap").text
        print(i, title, link, content)
        ws.append([title, link, content])

 html = response.text
    soup = BeautifulSoup(html, 'html.parser')

    # 10개 기사 덩어리 가져오기
    articles = soup.select(".news_area")
        
wb.save(f"{keyword}.xlsx")
# Out:
#   File <tokenize>:16
#     html = response.text
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
main_keyword = input('검색어를 입력하세요: ')
sub_list = ['ㄱ', 'ㄴ', 'ㄷ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅅ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']

wb = openpyxl.Workbook() # 워크북 생성
ws = wb.active # 현재 활성화된 sheet 선택
ws.title = main_keyword # sheet 이름 변경


ws['A1'] = main_keyword + '유튜브연관키워드 추출결과'
ws.append(['순번', '연관키워드'])

count = 1
for sub in sub_list:
    keyword = main_keyword + ' ' + sub
    response = requests.get(f"https://ac.search.naver.com/nx/ac?q={keyword}&con=0&frm=nv&ans=2&r_format=json&r_enc=UTF-8&r_unicode=0&t_koreng=1&run=2&rev=4&q_enc=UTF-8&st=100&_callback=")
    data = response.text
    
    data = json.loads(data)
    items = data['items'][0]
    for item in items:
        print(item[0])
        ws.append([count, item[0]])
        count += 1
        
        
wb.save(f"{main_keyword} 연관키워드.xlsx")
# Out:
# 메이플스토리 갤러리
# 메이플스토리 굿즈
# 메이플스토리 글꼴
# 메이플스토리 결말
# 메이플스토리 경험치
# 메이플스토리 경매장
# 메이플스토리 골드리치의 비밀금고
# 메이플스토리 고사성어 레벨업
# 메이플스토리 공식 가이드북
# 메이플스토리 공식 아트북
# 메이플스토리 닉네임
# 메이플스토리 넥슨
# 메이플스토리 네이버
# 메이플스토리 나이트로드
# 메이플스토리 노바의 성역 판테온
# 메이플스토리 논술레벨업
# 메이플스토리 논술레벨업 세트
# 메이플 스토리 논리퍼즐 1vs100
# 메이플스토리 도도
# 메이플스토리 돼지
# 메이플스토리 도적
# 메이플스토리 다운로드
# 메이플스토리 다이아곡괭이
# 메이플스토리 다운
# 메이플스토리 두뇌퍼즐 1 vs 100
# 심포니 오브 메이플스토리 대구
# 메이플스토리 링크
# 메이플스토리 라라
# 메이플스토리 랭킹
# 메이플스토리 로얄
# 메이플스토리 리부트
# 메이플스토리 루시드
# 메이플스토리 라라 스킬트리
# 메이플스토리 링크스킬
# 메이플스토리 로고
# 메이플스토리 리부트 사냥터
# 메이플스토리 만화
# 메이플스토리 만화책
# 메이플스토리 몬스터
# 메이플스토리 머리
# 메이플스토리 메소
# 메이플스토리 맵
# 메이플스토리 모험가
# 메이플스토리 무자본
# 메이플스토리 마법사
# 메이플스토리 메르세데스
# 메이플스토리 버섯
# 메이플스토리 버닝
# 메이플스토리 비숍
# 메이플스토리 보스
# 메이플스토리 불독
# 메이플스토리 발록
# 메이플스토리 비밀금고
# 메이플스토리 반짝반짝 두뇌게임북
# 메이플스토리봉제인형(대)-페페
# 메이플스토리봉제인형(소)-주황버섯
# 메이플스토리 사냥터
# 메이플스토리 슬라임
# 메이플스토리 서버
# 메이플스토리 스티커
# 메이플스토리 사양
# 메이플스토리 신직업
# 메이플스토리 소울마스터
# 메이플스토리 성형
# 메이플스토리 신궁
# 메이플스토리 사자성어 레벨업
# 메이플스토리 인벤
# 메이플스토리 월드
# 메이플스토리 이벤트
# 메이플스토리 유니온
# 메이플스토리 예티
# ...
